# %%
import pandas as pdv
import seaborn as sns
import numpy as nm
df = pdv.read_csv("crops.csv").fillna(0)
df.head()
# Out:
#   County/Sub County     Total    Farming  Crop Production  \
# 0             KENYA  12143913  6354211.0          5555974
# 1           MOMBASA    378422    12497.0             7218
# 2         CHANGAMWE     46614      618.0              230
# 3             JOMVU     53472     2418.0             1168
# 4           KISAUNI     88202     6257.0             4043
#
#    Livestock Production  Aquaculture  Fishing  Irrigation      Maize  \
# 0               4729288        29325   109640      369679  5104967.0
# 1                  8749          128     1409         958     5681.0
# 2                   476            6       62          36      108.0
# 3                  1810           12      132         209      895.0
# 4                  4269           67      492         402     3456.0
#
#     Sorghum  ...    Camels  Donkeys      Pigs  Indigenous Chicken  \
# 0  904945.0  ...  167666.0   500682  110383.0             3337700
# ...

# %%
df.describe(include='object')
# Out:
#        County/Sub County
# count                393
# unique               376
# top     MT. KENYA FOREST
# freq                   5

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
